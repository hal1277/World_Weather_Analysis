# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tezu
# Processing Record 2 of Set 1 | kamaishi
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | kulachi
# Processing Record 6 of Set 1 | mwanza
# Processing Record 7 of Set 1 | hami
# Processing Record 8 of Set 1 | manggar
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | katherine
# Processing Record 11 of Set 1 | upata
# Processing Record 12 of Set 1 | atherton
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | uong bi
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | port blair
# Processing Record 22 of Set 1 | shimoda
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | bilibino
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | gawler
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | patan
# Processing Record 35 of Set 1 | hendijan
# City not found. Skipping...
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | cap-chat
# Processing Record 41 of Set 1 | alyangula
# Processing Record 42 of Set 1 | pimenteiras
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | oussouye
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | port macquarie
# Processing Record 48 of Set 1 | aquiraz
# Processing Record 49 of Set 1 | baiyin
# Processing Record 50 of Set 1 | skeldon
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | victoria
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | carutapera
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | haines junction
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | mehamn
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | vardo
# Processing Record 13 of Set 2 | vero beach
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | yulara
# Processing Record 16 of Set 2 | nome
# Processing Record 17 of Set 2 | iquique
# Processing Record 18 of Set 2 | avera
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | marialva
# Processing Record 22 of Set 2 | cochrane
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | klaksvik
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | vredendal
# Processing Record 27 of Set 2 | sakakah
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | jyvaskyla
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | khargapur
# Processing Record 34 of Set 2 | kalmunai
# Processing Record 35 of Set 2 | nanfeng
# Processing Record 36 of Set 2 | dalvik
# Processing Record 37 of Set 2 | salalah
# Processing Record 38 of Set 2 | lompoc
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | mounana
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | rundu
# Processing Record 44 of Set 2 | pavilosta
# Processing Record 45 of Set 2 | bolitoc
# Processing Record 46 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 2 | galesong
# Processing Record 48 of Set 2 | puerto escondido
# Processing Record 49 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 50 of Set 2 | tallahassee
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | cortez
# Processing Record 4 of Set 3 | jind
# Processing Record 5 of Set 3 | talcahuano
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | manadhoo
# Processing Record 8 of Set 3 | goderich
# Processing Record 9 of Set 3 | san mateo ixtatan
# Processing Record 10 of Set 3 | charters towers
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | urumqi
# Processing Record 16 of Set 3 | tuatapere
# Processing Record 17 of Set 3 | san policarpo
# Processing Record 18 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 3 | geraldton
# Processing Record 20 of Set 3 | berck
# Processing Record 21 of Set 3 | vao
# Processing Record 22 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 3 | ariquemes
# Processing Record 24 of Set 3 | ondjiva
# Processing Record 25 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 3 | nampula
# Processing Record 27 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 3 | okhotsk
# Processing Record 29 of Set 3 | necochea
# Processing Record 30 of Set 3 | paita
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | flinders
# Processing Record 33 of Set 3 | mobaye
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | sechura
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | jumla
# Processing Record 38 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 3 | sharjah
# Processing Record 40 of Set 3 | palmer
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | shanghai
# Processing Record 43 of Set 3 | bethel
# Processing Record 44 of Set 3 | dickinson
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | walvis bay
# Processing Record 47 of Set 3 | sao felix do xingu
# Processing Record 48 of Set 3 | sokolov
# Processing Record 49 of Set 3 | dhadar
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | herat
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | grand gaube
# Processing Record 4 of Set 4 | aklavik
# Processing Record 5 of Set 4 | coihaique
# Processing Record 6 of Set 4 | khatanga
# Processing Record 7 of Set 4 | nyuksenitsa
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | durango
# Processing Record 10 of Set 4 | sapouy
# Processing Record 11 of Set 4 | axim
# Processing Record 12 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 4 | mackay
# Processing Record 14 of Set 4 | san ramon
# Processing Record 15 of Set 4 | dire
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | altay
# Processing Record 18 of Set 4 | cabedelo
# Processing Record 19 of Set 4 | san rafael
# Processing Record 20 of Set 4 | hay river
# Processing Record 21 of Set 4 | haizhou
# Processing Record 22 of Set 4 | gillette
# Processing Record 23 of Set 4 | hurghada
# Processing Record 24 of Set 4 | kununurra
# Processing Record 25 of Set 4 | belaya gora
# Processing Record 26 of Set 4 | port augusta
# Processing Record 27 of Set 4 | isangel
# Processing Record 28 of Set 4 | mount abu
# Processing Record 29 of Set 4 | nicoya
# Processing Record 30 of Set 4 | kaitangata
# Processing Record 31 of Set 4 | husavik
# Processing Record 32 of Set 4 | chuy
# Processing Record 33 of Set 4 | maryville
# Processing Record 34 of Set 4 | chifeng
# Processing Record 35 of Set 4 | uinskoye
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | tarauaca
# Processing Record 38 of Set 4 | zhangjiakou
# Processing Record 39 of Set 4 | fort nelson
# Processing Record 40 of Set 4 | amga
# Processing Record 41 of Set 4 | cockburn town
# Processing Record 42 of Set 4 | luderitz
# Processing Record 43 of Set 4 | fairbanks
# Processing Record 44 of Set 4 | fortuna
# Processing Record 45 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 46 of Set 4 | torres
# Processing Record 47 of Set 4 | omboue
# Processing Record 48 of Set 4 | port hardy
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | dalby
# Processing Record 1 of Set 5 | karratha
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | oranjemund
# Processing Record 4 of Set 5 | loandjili
# Processing Record 5 of Set 5 | bandarbeyla
# Processing Record 6 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | acajutla
# Processing Record 10 of Set 5 | tynda
# Processing Record 11 of Set 5 | nanortalik
# Processing Record 12 of Set 5 | abbeville
# Processing Record 13 of Set 5 | nikolskoye
# Processing Record 14 of Set 5 | dakar
# Processing Record 15 of Set 5 | tura
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | babol
# Processing Record 18 of Set 5 | nemuro
# Processing Record 19 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 5 | gizo
# Processing Record 21 of Set 5 | havelock
# Processing Record 22 of Set 5 | champerico
# Processing Record 23 of Set 5 | pangnirtung
# Processing Record 24 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 5 | san antonio
# Processing Record 26 of Set 5 | vanavara
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | san miguel
# Processing Record 29 of Set 5 | cartagena
# Processing Record 30 of Set 5 | sao jose do calcado
# Processing Record 31 of Set 5 | changping
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | shache
# Processing Record 34 of Set 5 | cururupu
# Processing Record 35 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 5 | price
# Processing Record 37 of Set 5 | carupano
# Processing Record 38 of Set 5 | severo-yeniseyskiy
# Processing Record 39 of Set 5 | wajima
# Processing Record 40 of Set 5 | kawalu
# Processing Record 41 of Set 5 | la ronge
# Processing Record 42 of Set 5 | mayen
# Processing Record 43 of Set 5 | san carlos de bariloche
# Processing Record 44 of Set 5 | barkhan
# Processing Record 45 of Set 5 | praia da vitoria
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | mexico
# Processing Record 48 of Set 5 | kargasok
# Processing Record 49 of Set 5 | kavaratti
# Processing Record 50 of Set 5 | pak thong chai
# Processing Record 1 of Set 6 | huarmey
# Processing Record 2 of Set 6 | kutum
# Processing Record 3 of Set 6 | saint-pierre
# Processing Record 4 of Set 6 | batangafo
# Processing Record 5 of Set 6 | ilulissat
# Processing Record 6 of Set 6 | portland
# Processing Record 7 of Set 6 | amazar
# Processing Record 8 of Set 6 | maniitsoq
# Processing Record 9 of Set 6 | mandera
# Processing Record 10 of Set 6 | westport
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | blessington
# Processing Record 13 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 6 | okitipupa
# Processing Record 15 of Set 6 | enshi
# Processing Record 16 of Set 6 | beringovskiy
# Processing Record 17 of Set 6 | makokou
# Processing Record 18 of Set 6 | bocana de paiwas
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | sindor
# Processing Record 21 of Set 6 | khanpur
# Processing Record 22 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | coffs harbour
# Processing Record 25 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 6 | fort walton beach
# Processing Record 27 of Set 6 | talnakh
# Processing Record 28 of Set 6 | tottori
# Processing Record 29 of Set 6 | namtsy
# Processing Record 30 of Set 6 | louga
# Processing Record 31 of Set 6 | srednekolymsk
# Processing Record 32 of Set 6 | cochabamba
# Processing Record 33 of Set 6 | tamra
# Processing Record 34 of Set 6 | inuvik
# Processing Record 35 of Set 6 | santa isabel do rio negro
# Processing Record 36 of Set 6 | keelung
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | cidreira
# Processing Record 39 of Set 6 | iwanai
# Processing Record 40 of Set 6 | nizwa
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | svetlogorsk
# Processing Record 44 of Set 6 | puerto gaitan
# Processing Record 45 of Set 6 | kendari
# Processing Record 46 of Set 6 | bumba
# Processing Record 47 of Set 6 | pevek
# Processing Record 48 of Set 6 | manacor
# Processing Record 49 of Set 6 | wladyslawowo
# Processing Record 50 of Set 6 | okato
# Processing Record 1 of Set 7 | russell
# Processing Record 2 of Set 7 | komsomolskiy
# Processing Record 3 of Set 7 | tacuarembo
# Processing Record 4 of Set 7 | mogadishu
# Processing Record 5 of Set 7 | hofn
# Processing Record 6 of Set 7 | ahuimanu
# Processing Record 7 of Set 7 | haverfordwest
# Processing Record 8 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 7 | itarema
# Processing Record 10 of Set 7 | chivay
# Processing Record 11 of Set 7 | sinnamary
# Processing Record 12 of Set 7 | port lincoln
# Processing Record 13 of Set 7 | khasan
# Processing Record 14 of Set 7 | iqaluit
# Processing Record 15 of Set 7 | bonanza
# Processing Record 16 of Set 7 | jiuquan
# Processing Record 17 of Set 7 | bundaberg
# Processing Record 18 of Set 7 | gat
# Processing Record 19 of Set 7 | kodinsk
# Processing Record 20 of Set 7 | burica
# City not found. Skipping...
# Processing Record 21 of Set 7 | dingle
# Processing Record 22 of Set 7 | kavieng
# Processing Record 23 of Set 7 | georgetown
# Processing Record 24 of Set 7 | lisakovsk
# Processing Record 25 of Set 7 | trat
# Processing Record 26 of Set 7 | pacific grove
# Processing Record 27 of Set 7 | zheleznodorozhnyy
# Processing Record 28 of Set 7 | ossora
# Processing Record 29 of Set 7 | cankuzo
# Processing Record 30 of Set 7 | katangli
# Processing Record 31 of Set 7 | port hedland
# Processing Record 32 of Set 7 | hohhot
# Processing Record 33 of Set 7 | biak
# Processing Record 34 of Set 7 | yumen
# Processing Record 35 of Set 7 | xiangdong
# City not found. Skipping...
# Processing Record 36 of Set 7 | daru
# Processing Record 37 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 7 | zhitikara
# City not found. Skipping...
# Processing Record 39 of Set 7 | camacha
# Processing Record 40 of Set 7 | christchurch
# Processing Record 41 of Set 7 | sabzevar
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | mut
# Processing Record 44 of Set 7 | demba
# Processing Record 45 of Set 7 | vilyuysk
# Processing Record 46 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 47 of Set 7 | sao joao da barra
# Processing Record 48 of Set 7 | coahuayana
# Processing Record 49 of Set 7 | lata
# Processing Record 50 of Set 7 | celestun
# Processing Record 1 of Set 8 | maxixe
# Processing Record 2 of Set 8 | botwood
# Processing Record 3 of Set 8 | hovd
# Processing Record 4 of Set 8 | bengkulu
# Processing Record 5 of Set 8 | yerbogachen
# Processing Record 6 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 8 | livingston
# Processing Record 8 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 8 | pyinmana
# Processing Record 10 of Set 8 | callaway
# Processing Record 11 of Set 8 | rocha
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | sisimiut
# Processing Record 14 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 8 | hualmay
# Processing Record 16 of Set 8 | saint-leger
# Processing Record 17 of Set 8 | monrovia
# Processing Record 18 of Set 8 | victoria point
# Processing Record 19 of Set 8 | matay
# Processing Record 20 of Set 8 | kasongo-lunda
# Processing Record 21 of Set 8 | jaicos
# Processing Record 22 of Set 8 | betsiamites
# Processing Record 23 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 24 of Set 8 | cape coast
# Processing Record 25 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 8 | broome
# Processing Record 27 of Set 8 | akividu
# Processing Record 28 of Set 8 | college
# Processing Record 29 of Set 8 | les cayes
# Processing Record 30 of Set 8 | bialystok
# Processing Record 31 of Set 8 | debre birhan
# Processing Record 32 of Set 8 | caxito
# Processing Record 33 of Set 8 | palm coast
# Processing Record 34 of Set 8 | mangrol
# Processing Record 35 of Set 8 | dajal
# Processing Record 36 of Set 8 | deyang
# Processing Record 37 of Set 8 | aktau
# Processing Record 38 of Set 8 | kudahuvadhoo
# Processing Record 39 of Set 8 | namatanai
# Processing Record 40 of Set 8 | launceston
# Processing Record 41 of Set 8 | ketchikan
# Processing Record 42 of Set 8 | bathsheba
# Processing Record 43 of Set 8 | narsaq
# Processing Record 44 of Set 8 | upernavik
# Processing Record 45 of Set 8 | batagay-alyta
# Processing Record 46 of Set 8 | labuhan
# Processing Record 47 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 8 | southbridge
# Processing Record 49 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 8 | namwala
# Processing Record 1 of Set 9 | chulym
# Processing Record 2 of Set 9 | wajir
# Processing Record 3 of Set 9 | samarai
# Processing Record 4 of Set 9 | sao caitano
# Processing Record 5 of Set 9 | ukiah
# Processing Record 6 of Set 9 | alofi
# Processing Record 7 of Set 9 | harper
# Processing Record 8 of Set 9 | filingue
# Processing Record 9 of Set 9 | marystown
# Processing Record 10 of Set 9 | boddam
# Processing Record 11 of Set 9 | jambi
# Processing Record 12 of Set 9 | lavrentiya
# Processing Record 13 of Set 9 | port elizabeth
# Processing Record 14 of Set 9 | ozark
# Processing Record 15 of Set 9 | erbaa
# Processing Record 16 of Set 9 | formosa do rio preto
# Processing Record 17 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 9 | troitskoye
# Processing Record 19 of Set 9 | mogok
# Processing Record 20 of Set 9 | madang
# Processing Record 21 of Set 9 | vila franca do campo
# Processing Record 22 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 9 | pekan
# Processing Record 24 of Set 9 | narasannapeta
# Processing Record 25 of Set 9 | smolenka
# Processing Record 26 of Set 9 | punta alta
# Processing Record 27 of Set 9 | bosanska krupa
# Processing Record 28 of Set 9 | kruisfontein
# Processing Record 29 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 9 | awbari
# Processing Record 31 of Set 9 | san jeronimo
# Processing Record 32 of Set 9 | smithers
# Processing Record 33 of Set 9 | sorong
# Processing Record 34 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 9 | colares
# Processing Record 36 of Set 9 | dourbali
# Processing Record 37 of Set 9 | constantine
# Processing Record 38 of Set 9 | tiksi
# Processing Record 39 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 9 | dehloran
# Processing Record 41 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 9 | dutlwe
# Processing Record 43 of Set 9 | sedro-woolley
# Processing Record 44 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 9 | saldanha
# Processing Record 46 of Set 9 | saint-joseph
# Processing Record 47 of Set 9 | camalu
# Processing Record 48 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 49 of Set 9 | broken hill
# Processing Record 50 of Set 9 | labytnangi
# Processing Record 1 of Set 10 | raga
# Processing Record 2 of Set 10 | miastko
# Processing Record 3 of Set 10 | amot
# Processing Record 4 of Set 10 | sterling
# Processing Record 5 of Set 10 | barcelos
# Processing Record 6 of Set 10 | bondo
# Processing Record 7 of Set 10 | chatellerault
# Processing Record 8 of Set 10 | fare
# Processing Record 9 of Set 10 | lahij
# Processing Record 10 of Set 10 | codrington
# Processing Record 11 of Set 10 | tanga
# Processing Record 12 of Set 10 | xingcheng
# Processing Record 13 of Set 10 | mathbaria
# Processing Record 14 of Set 10 | along
# Processing Record 15 of Set 10 | bubaque
# Processing Record 16 of Set 10 | gao
# Processing Record 17 of Set 10 | vestmannaeyjar
# Processing Record 18 of Set 10 | agva
# City not found. Skipping...
# Processing Record 19 of Set 10 | mount isa
# Processing Record 20 of Set 10 | turochak
# Processing Record 21 of Set 10 | jackson
# Processing Record 22 of Set 10 | miramar
# Processing Record 23 of Set 10 | qui nhon
# Processing Record 24 of Set 10 | san jose
# Processing Record 25 of Set 10 | saint anthony
# Processing Record 26 of Set 10 | riyadh
# Processing Record 27 of Set 10 | mutoko
# Processing Record 28 of Set 10 | margate
# Processing Record 29 of Set 10 | basco
# Processing Record 30 of Set 10 | elko
# Processing Record 31 of Set 10 | krasnogorsk
# Processing Record 32 of Set 10 | purpe
# Processing Record 33 of Set 10 | hobbs
# Processing Record 34 of Set 10 | bacolod
# Processing Record 35 of Set 10 | taoudenni
# Processing Record 36 of Set 10 | arman
# Processing Record 37 of Set 10 | naze
# Processing Record 38 of Set 10 | cascais
# Processing Record 39 of Set 10 | hambantota
# Processing Record 40 of Set 10 | constitucion
# Processing Record 41 of Set 10 | ust-kuyga
# Processing Record 42 of Set 10 | sept-iles
# Processing Record 43 of Set 10 | clarksdale
# Processing Record 44 of Set 10 | umtata
# Processing Record 45 of Set 10 | seoul
# Processing Record 46 of Set 10 | kyra
# Processing Record 47 of Set 10 | maceio
# Processing Record 48 of Set 10 | kapit
# Processing Record 49 of Set 10 | zapolyarnyy
# Processing Record 50 of Set 10 | port hueneme
# Processing Record 1 of Set 11 | nouadhibou
# Processing Record 2 of Set 11 | visnes
# Processing Record 3 of Set 11 | datong
# Processing Record 4 of Set 11 | tautira
# Processing Record 5 of Set 11 | southern pines
# Processing Record 6 of Set 11 | tricase
# Processing Record 7 of Set 11 | touros
# Processing Record 8 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 11 | leningradskiy
# Processing Record 10 of Set 11 | udachnyy
# Processing Record 11 of Set 11 | waingapu
# Processing Record 12 of Set 11 | winnemucca
# Processing Record 13 of Set 11 | ushtobe
# Processing Record 14 of Set 11 | falun
# Processing Record 15 of Set 11 | chaah
# Processing Record 16 of Set 11 | berlevag
# Processing Record 17 of Set 11 | fort-shevchenko
# Processing Record 18 of Set 11 | sola
# Processing Record 19 of Set 11 | dahuk
# Processing Record 20 of Set 11 | yabelo
# Processing Record 21 of Set 11 | meulaboh
# Processing Record 22 of Set 11 | roald
# Processing Record 23 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 24 of Set 11 | papara
# Processing Record 25 of Set 11 | camana
# Processing Record 26 of Set 11 | orthez
# Processing Record 27 of Set 11 | denpasar
# Processing Record 28 of Set 11 | isoka
# Processing Record 29 of Set 11 | ostersund
# Processing Record 30 of Set 11 | lazaro cardenas
# Processing Record 31 of Set 11 | mezen
# Processing Record 32 of Set 11 | erzin
# Processing Record 33 of Set 11 | okha
# Processing Record 34 of Set 11 | vondrozo
# Processing Record 35 of Set 11 | deputatskiy
# Processing Record 36 of Set 11 | macedo de cavaleiros
# Processing Record 37 of Set 11 | raduzhnyy
# Processing Record 38 of Set 11 | kaeo
# Processing Record 39 of Set 11 | veliki preslav
# Processing Record 40 of Set 11 | miri
# Processing Record 41 of Set 11 | unguia
# Processing Record 42 of Set 11 | tamiahua
# Processing Record 43 of Set 11 | teguise
# Processing Record 44 of Set 11 | mabaruma
# Processing Record 45 of Set 11 | te anau
# Processing Record 46 of Set 11 | dwarka
# Processing Record 47 of Set 11 | lensk
# Processing Record 48 of Set 11 | pochutla
# Processing Record 49 of Set 11 | kokopo
# Processing Record 50 of Set 11 | aswan
# Processing Record 1 of Set 12 | swift current
# Processing Record 2 of Set 12 | cayenne
# Processing Record 3 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 12 | dumas
# Processing Record 5 of Set 12 | cabo san lucas
# Processing Record 6 of Set 12 | zhigansk
# Processing Record 7 of Set 12 | sri aman
# Processing Record 8 of Set 12 | ormara
# Processing Record 9 of Set 12 | nantucket
# Processing Record 10 of Set 12 | kushima
# Processing Record 11 of Set 12 | skibbereen
# Processing Record 12 of Set 12 | wukari
# Processing Record 13 of Set 12 | vallenar
# Processing Record 14 of Set 12 | zhuzhou
# Processing Record 15 of Set 12 | manokwari
# Processing Record 16 of Set 12 | bellmore
# Processing Record 17 of Set 12 | jaguarao
# Processing Record 18 of Set 12 | mantua
# Processing Record 19 of Set 12 | davila
# Processing Record 20 of Set 12 | nedumangad
# Processing Record 21 of Set 12 | guangzhou
# Processing Record 22 of Set 12 | saurimo
# Processing Record 23 of Set 12 | caohe
# Processing Record 24 of Set 12 | north bend
# Processing Record 25 of Set 12 | cimitarra
# Processing Record 26 of Set 12 | quatre cocos
# Processing Record 27 of Set 12 | henties bay
# Processing Record 28 of Set 12 | chinhoyi
# Processing Record 29 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 12 | yuncheng
# Processing Record 31 of Set 12 | noshiro
# Processing Record 32 of Set 12 | sibolga
# Processing Record 33 of Set 12 | mvuma
# Processing Record 34 of Set 12 | jacareacanga
# Processing Record 35 of Set 12 | ocos
# Processing Record 36 of Set 12 | yatou
# Processing Record 37 of Set 12 | katsuura
# Processing Record 38 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 12 | stawell
# Processing Record 40 of Set 12 | umba
# Processing Record 41 of Set 12 | teahupoo
# Processing Record 42 of Set 12 | robertsport
# Processing Record 43 of Set 12 | beloha
# Processing Record 44 of Set 12 | andros town
# Processing Record 45 of Set 12 | iralaya
# Processing Record 46 of Set 12 | northam
# Processing Record 47 of Set 12 | mithimna
# City not found. Skipping...
# Processing Record 48 of Set 12 | tera
# Processing Record 49 of Set 12 | byron bay
# Processing Record 50 of Set 12 | snyder
# Processing Record 1 of Set 13 | fukue
# Processing Record 2 of Set 13 | la uribe
# City not found. Skipping...
# Processing Record 3 of Set 13 | pangody
# Processing Record 4 of Set 13 | dali
# Processing Record 5 of Set 13 | inverness
# Processing Record 6 of Set 13 | lagoa
# Processing Record 7 of Set 13 | santo antonio do monte
# Processing Record 8 of Set 13 | brae
# Processing Record 9 of Set 13 | tessalit
# Processing Record 10 of Set 13 | wanning
# Processing Record 11 of Set 13 | corowa
# Processing Record 12 of Set 13 | batsfjord
# Processing Record 13 of Set 13 | lodja
# Processing Record 14 of Set 13 | cukai
# Processing Record 15 of Set 13 | nalut
# Processing Record 16 of Set 13 | felipe carrillo puerto
# Processing Record 17 of Set 13 | sukhothai
# Processing Record 18 of Set 13 | egvekinot
# Processing Record 19 of Set 13 | rio gallegos
# Processing Record 20 of Set 13 | tommot
# Processing Record 21 of Set 13 | dahra
# Processing Record 22 of Set 13 | oistins
# Processing Record 23 of Set 13 | lima
# Processing Record 24 of Set 13 | tahta
# Processing Record 25 of Set 13 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 26 of Set 13 | lamesa
# Processing Record 27 of Set 13 | amalapuram
# Processing Record 28 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 29 of Set 13 | colesberg
# Processing Record 30 of Set 13 | inderka
# Processing Record 31 of Set 13 | baranain
# Processing Record 32 of Set 13 | beitbridge
# Processing Record 33 of Set 13 | honiara
# Processing Record 34 of Set 13 | mezhdurechensk
# Processing Record 35 of Set 13 | hereford
# Processing Record 36 of Set 13 | cravo norte
# Processing Record 37 of Set 13 | sioux lookout
# Processing Record 38 of Set 13 | tibati
# Processing Record 39 of Set 13 | nizhnevartovsk
# Processing Record 40 of Set 13 | saint-augustin
# Processing Record 41 of Set 13 | feijo
# Processing Record 42 of Set 13 | rawson
# Processing Record 43 of Set 13 | alacranes
# Processing Record 44 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 13 | maldonado
# Processing Record 46 of Set 13 | taltal
# Processing Record 47 of Set 13 | tilichiki
# Processing Record 48 of Set 13 | kangaba
# Processing Record 49 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 13 | ponta delgada
# Processing Record 1 of Set 14 | kulu
# Processing Record 2 of Set 14 | vila
# Processing Record 3 of Set 14 | gladstone
# Processing Record 4 of Set 14 | vanimo
# Processing Record 5 of Set 14 | ostrovnoy
# Processing Record 6 of Set 14 | guhagar
# Processing Record 7 of Set 14 | dawson creek
# Processing Record 8 of Set 14 | maringa
# Processing Record 9 of Set 14 | dortyol
# Processing Record 10 of Set 14 | poum
# Processing Record 11 of Set 14 | arlit
# Processing Record 12 of Set 14 | baruun-urt
# Processing Record 13 of Set 14 | ugra
# Processing Record 14 of Set 14 | macae
# Processing Record 15 of Set 14 | grindavik
# Processing Record 16 of Set 14 | menzelinsk
# Processing Record 17 of Set 14 | borovskoy
# Processing Record 18 of Set 14 | kirakira
# Processing Record 19 of Set 14 | wufeng
# Processing Record 20 of Set 14 | fort dodge
# Processing Record 21 of Set 14 | hamilton
# Processing Record 22 of Set 14 | piterka
# Processing Record 23 of Set 14 | huron
# Processing Record 24 of Set 14 | korla
# Processing Record 25 of Set 14 | palana
# Processing Record 26 of Set 14 | benghazi
# Processing Record 27 of Set 14 | turukhansk
# Processing Record 28 of Set 14 | ancud
# Processing Record 29 of Set 14 | ostrowiec swietokrzyski
# Processing Record 30 of Set 14 | adelaide
# Processing Record 31 of Set 14 | lethem
# Processing Record 32 of Set 14 | ewa beach
# Processing Record 33 of Set 14 | bairiki
# Processing Record 34 of Set 14 | haicheng
# Processing Record 35 of Set 14 | sabang
# Processing Record 36 of Set 14 | almenevo
# City not found. Skipping...
# Processing Record 37 of Set 14 | xining
# Processing Record 38 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 14 | umea
# Processing Record 40 of Set 14 | kinablangan
# Processing Record 41 of Set 14 | blackfoot
# Processing Record 42 of Set 14 | wellington
# Processing Record 43 of Set 14 | high level
# Processing Record 44 of Set 14 | asau
# Processing Record 45 of Set 14 | thohoyandou
# Processing Record 46 of Set 14 | gazanjyk
# Processing Record 47 of Set 14 | phayakkhaphum phisai
# Processing Record 48 of Set 14 | hurricane
# Processing Record 49 of Set 14 | vila velha
# Processing Record 50 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 15 | uyemskiy
# Processing Record 2 of Set 15 | muravlenko
# Processing Record 3 of Set 15 | qaqortoq
# Processing Record 4 of Set 15 | finschhafen
# Processing Record 5 of Set 15 | vitoria da conquista
# Processing Record 6 of Set 15 | olinda
# Processing Record 7 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 8 of Set 15 | andenes
# Processing Record 9 of Set 15 | moranbah
# Processing Record 10 of Set 15 | havoysund
# Processing Record 11 of Set 15 | parrita
# Processing Record 12 of Set 15 | chapais
# Processing Record 13 of Set 15 | san vicente
# Processing Record 14 of Set 15 | yeppoon
# Processing Record 15 of Set 15 | kenai
# Processing Record 16 of Set 15 | mocuba
# Processing Record 17 of Set 15 | rio bueno
# Processing Record 18 of Set 15 | gamba
# Processing Record 19 of Set 15 | horsham
# Processing Record 20 of Set 15 | orocue
# Processing Record 21 of Set 15 | belyy yar
# Processing Record 22 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 15 | moose factory
# Processing Record 24 of Set 15 | sembakung
# Processing Record 25 of Set 15 | ulaangom
# Processing Record 26 of Set 15 | richards bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tezu  27.9167   96.1667     74.21        34          45
# 1      Kamaishi  39.2667  141.8833     50.95        51          35
# 2       Mataura -46.1927  168.8643     62.47        45          93
# 3        Hobart -42.8794  147.3294     83.01        35          20
# 4       Kulachi  31.9286   70.4592     64.15        24          99
# 5        Mwanza  -2.5167   32.9000     69.89        79          98
# 6          Hami  42.8000   93.4500     26.49        52          23
# 7       Manggar  -2.8833  108.2667     85.75        63          79
# 8  Punta Arenas -53.1500  -70.9167     46.51        76          40
# 9     Katherine -14.4667  132.2667    100.72        19          40
#
#    Wind Speed Country       Description
# 0        1.48      IN  scattered clouds
# 1        9.69      JP  scattered clouds
# 2        6.98      NZ   overcast clouds
# 3        3.00      AU        few clouds
# 4        5.82      PK   overcast clouds
# 5        6.26      TZ        light rain
# 6        2.44      CN        few clouds
# 7        0.54      ID     broken clouds
# 8       10.36      CL  scattered clouds
# 9       13.80      AU  scattered clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Tezu      IN  27.9167   96.1667     74.21        34          45
# 1         Kamaishi      JP  39.2667  141.8833     50.95        51          35
# 2          Mataura      NZ -46.1927  168.8643     62.47        45          93
# 3           Hobart      AU -42.8794  147.3294     83.01        35          20
# 4          Kulachi      PK  31.9286   70.4592     64.15        24          99
# ..             ...     ...      ...       ...       ...       ...         ...
# 659      Belyy Yar      RU  53.6039   91.3903      8.49        85          99
# 660  Moose Factory      CA  51.2585  -80.6094     12.20        92          90
# 661      Sembakung      ID   3.8167  117.2500     85.93        54          90
# 662       Ulaangom      MN  49.9811   92.0667     14.14        77          71
# 663   Richards Bay      ZA -28.7830   32.0377     73.18        82         100
#
#      Wind Speed       Description
# 0          1.48  scattered clouds
# 1          9.69  scattered clouds
# 2          6.98   overcast clouds
# 3          3.00        few clouds
# 4          5.82   overcast clouds
# ..          ...               ...
# 659        0.00             smoke
# 660        3.44   overcast clouds
# 661        2.35   overcast clouds
# 662        1.10     broken clouds
# 663       11.07   overcast clouds
#
# [664 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
